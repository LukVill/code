# %% [markdown]
# # Problem 7
#
# \begin{gather*}
#
# P_{0,1,2,3} = \frac{(x-x_0)P_{1,2,3}(x) - (x-x_3)P_{0,1,2}(x)}{x_3 - x_0} \\
#
# \implies \\
#
# 3.016 = \frac{(0.4)2.96 - (0.4-0.75)P_{0,1,2}(0.4)}{0.75} \\
#
# \implies \\
#
# P_{0,1,2}(0.4) = \frac{2.262 - 1.184}{0.35} \\
#
# \implies \\
#
# P_{0,1,2}(0.4) = 3.08 \\\\
#
#
# P_{0,1,2}(x) = \frac{(x - x_0)P_{1,2}(x) - (x - x_2)P_{0,1}(x)}{x_2 - x_0} \\
#
# \implies \\
#
# 3.08 = \frac{(0.4)P_{1,2}(0.4) - (-0.1)(2.6)}{0.5} \\
#
# \implies \\
#
# P_{1,2}(0.4) = \frac{1.54 - 0.26}{0.4} \\
#
# \implies \\
#
# P_{1,2}(0.4) = 3.2 \\\\
#
# P_{1,2}(x) = \frac{(x - x_1) P_2(x) - (x - x_2) P_1(x)}{x_2 - x_1} \\
#
# \implies \\
#
# 3.2 = \frac{(0.15) P_2(0.4) - (-0.1)2}{0.25} \\
#
# \implies \\
#
# P_2(0.4) = P_2 = \frac{0.8 - 0.2}{0.15} \\
#
# \implies \\
#
# P_2 = 4
#
#
# \end{gather*}

# %% [markdown]
# # Problem 8
#
# \begin{gather*}
#
# P_{0,1,2}(x) = \frac{(x - x_0)P_{1,2}(x) - (x - x_2)P_{0,1}(x)}{x_2 - x_0} \\ \implies \\
#
# \frac{27}{7} = \frac{(0.5)P_{1,2}(0.5) - (-0.2)3.5}{\frac{7}{10}} \\ \implies \\
#
# P_{1,2}(0.5) = \frac{2.7 - 0.7}{0.5} \\ \implies \\
#
# P_{1,2}(0.5) = 4 \\\\
#
# P_{1,2}(x) = \frac{(x - x_1) P_2(x) - (x - x_2) P_1(x)}{x_2 - x_1} \\ \implies \\
#
# 4 = \frac{(3.6)P_2(0.5) - (-0.2)2.8}{0.3} \\ \implies \\
#
# P_2(0.5) = P_2 = \frac{1.2 - 0.56}{3.6} \\ \implies \\
# P_2 = 0.1\bar{7}
#
# \end{gather*}
